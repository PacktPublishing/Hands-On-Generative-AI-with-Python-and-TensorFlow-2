# %% [markdown]
# # Detecting Facial Landmarks using ```MTCNN```
#
# + Use MTCNN, a deep learning model to identify faces and landmarks
# + Use the detector to detect face and facial landmarks on a given image
# + Visualize the results

# %% [markdown]
# ## Install MTCNN

# %%
# !pip install pip install mtcnn
# Out:
# Requirement already satisfied: pip in /Users/swatigaur/opt/anaconda3/lib/python3.7/site-packages (20.0.2)
# Requirement already satisfied: install in /Users/swatigaur/opt/anaconda3/lib/python3.7/site-packages (1.3.3)
# Requirement already satisfied: mtcnn in /Users/swatigaur/opt/anaconda3/lib/python3.7/site-packages (0.1.0)
# Requirement already satisfied: opencv-python>=4.1.0 in /Users/swatigaur/opt/anaconda3/lib/python3.7/site-packages (from mtcnn) (4.4.0.42)
# Requirement already satisfied: keras>=2.0.0 in /Users/swatigaur/opt/anaconda3/lib/python3.7/site-packages (from mtcnn) (2.4.3)
# Requirement already satisfied: numpy>=1.14.5 in /Users/swatigaur/opt/anaconda3/lib/python3.7/site-packages (from opencv-python>=4.1.0->mtcnn) (1.18.1)
# Requirement already satisfied: scipy>=0.14 in /Users/swatigaur/opt/anaconda3/lib/python3.7/site-packages (from keras>=2.0.0->mtcnn) (1.4.1)
# Requirement already satisfied: h5py in /Users/swatigaur/opt/anaconda3/lib/python3.7/site-packages (from keras>=2.0.0->mtcnn) (2.10.0)
# Requirement already satisfied: pyyaml in /Users/swatigaur/opt/anaconda3/lib/python3.7/site-packages (from keras>=2.0.0->mtcnn) (5.3)
# Requirement already satisfied: six in /Users/swatigaur/opt/anaconda3/lib/python3.7/site-packages (from h5py->keras>=2.0.0->mtcnn) (1.14.0)

# %% [markdown]
# ## Load Libraries

# %%
from matplotlib import pyplot as plt
from matplotlib.patches import Rectangle, Circle
from mtcnn.mtcnn import MTCNN
import cv2

# %% [markdown]
# ## Utility function to mark and visualize results

# %%
def detect_faces(image, face_list):
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    ax = plt.gca()
    for face in face_list:
        # mark faces
        x, y, width, height = face['box']
        rect = Rectangle((x, y), width, height, fill=False, color='blue')
        ax.add_patch(rect)
        # mark landmark features
        for key, value in face['keypoints'].items():
            dot = Circle(value, radius=6, color='red')
            ax.add_patch(dot)
    plt.axis('off')
    plt.show()

# %% [markdown]
# ## Instantiate MTCNN detector

# %%
detector = MTCNN()

# %% [markdown]
# ## Load Sample Image

# %%
image = cv2.imread('faceswap_ed/trump_ref.png')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off');

# %% [markdown]
# ## Use MTCNN detector to identify face and landmark features

# %%
faces = detector.detect_faces(image)

# %% [markdown]
# ## Visualize Results

# %%
detect_faces(image, faces)
